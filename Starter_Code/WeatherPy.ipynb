# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
# from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 634

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = {}

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    # Parse the JSON and retrieve data
  
    try: 
        response = requests.get(city_url)
        responsejson = response.json()
        city_data[city] = responsejson

    except Exception as e:
        print(e)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | beitbridge
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | sentyabrskiy
# Processing Record 4 of Set 1 | ames
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | nanortalik
# Processing Record 8 of Set 1 | inuvik
# Processing Record 9 of Set 1 | leningradskiy
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | huangchuan
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | uwayl
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | vermilion
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | pacific grove
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | ancud
# Processing Record 20 of Set 1 | markala
# Processing Record 21 of Set 1 | cayenne
# Processing Record 22 of Set 1 | tasiilaq
# ...

# %%
city_data_arr = []

for city in city_data:

    # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
    city_details = city_data[city]
    
    if 'coord' in city_details.keys():
        pass
    else:
        # "City not found by open weather api"
        continue
        
    city_lat = city_details['coord']['lat']
    city_lng = city_details['coord']['lon']
    city_max_temp = city_details['main']['temp_max']
    city_humidity = city_details['main']['humidity']
    city_clouds = city_details['clouds']['all']
    city_wind = city_details['wind']['speed']
    city_country = city_details['sys']['country']
    city_date = city_details['dt']

    # Append the City information into city_data list
    city_data_arr.append({"City": city, 
                      "Lat": city_lat, 
                      "Lng": city_lng, 
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Country": city_country,
                      "Date": city_date})

print(city_data_arr)
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# [{'City': 'beitbridge', 'Lat': -22.2167, 'Lng': 30, 'Max Temp': 303.07, 'Humidity': 39, 'Cloudiness': 34, 'Wind Speed': 1.86, 'Country': 'ZW', 'Date': 1675707635}, {'City': 'albany', 'Lat': 42.6001, 'Lng': -73.9662, 'Max Temp': 277.8, 'Humidity': 74, 'Cloudiness': 99, 'Wind Speed': 1.79, 'Country': 'US', 'Date': 1675707513}, {'City': 'ames', 'Lat': 42.0347, 'Lng': -93.6199, 'Max Temp': 280.75, 'Humidity': 78, 'Cloudiness': 0, 'Wind Speed': 9.77, 'Country': 'US', 'Date': 1675707344}, {'City': 'rikitea', 'Lat': -23.1203, 'Lng': -134.9692, 'Max Temp': 298.84, 'Humidity': 74, 'Cloudiness': 16, 'Wind Speed': 2.55, 'Country': 'PF', 'Date': 1675707249}, {'City': 'cape town', 'Lat': -33.9258, 'Lng': 18.4232, 'Max Temp': 297.23, 'Humidity': 78, 'Cloudiness': 20, 'Wind Speed': 6.17, 'Country': 'ZA', 'Date': 1675707083}, {'City': 'nanortalik', 'Lat': 60.1432, 'Lng': -45.2371, 'Max Temp': 263.29, 'Humidity': 87, 'Cloudiness': 100, 'Wind Speed': 3.43, 'Country': 'GL', 'Date': 1675707636}, {'City'
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data_arr)

# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  beitbridge -22.2167   30.0000    303.07        39          34        1.86
# 1      albany  42.6001  -73.9662    277.80        74          99        1.79
# 2        ames  42.0347  -93.6199    280.75        78           0        9.77
# 3     rikitea -23.1203 -134.9692    298.84        74          16        2.55
# 4   cape town -33.9258   18.4232    297.23        78          20        6.17
#
#   Country        Date
# 0      ZW  1675707635
# 1      US  1675707513
# 2      US  1675707344
# 3      PF  1675707249
# 4      ZA  1675707083

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        beitbridge -22.2167   30.0000    303.07        39          34
# 1            albany  42.6001  -73.9662    277.80        74          99
# 2              ames  42.0347  -93.6199    280.75        78           0
# 3           rikitea -23.1203 -134.9692    298.84        74          16
# 4         cape town -33.9258   18.4232    297.23        78          20
#
#          Wind Speed Country        Date
# City_ID
# 0              1.86      ZW  1675707635
# 1              1.79      US  1675707513
# 2              9.77      US  1675707344
# 3              2.55      PF  1675707249
# 4              6.17      ZA  1675707083

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# Incorporate the other graph properties
plt.scatter(city_data_df.iloc[:,1],city_data_df.iloc[:,3])
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties
plt.scatter(city_data_df.iloc[:,1],city_data_df.iloc[:,4])
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# Incorporate the other graph properties
plt.scatter(city_data_df.iloc[:,1],city_data_df.iloc[:,5])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# Incorporate the other graph properties
plt.scatter(city_data_df.iloc[:,1],city_data_df.iloc[:,6])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1               albany  42.6001  -73.9662    277.80        74          99
# 2                 ames  42.0347  -93.6199    280.75        78           0
# 5           nanortalik  60.1432  -45.2371    263.29        87         100
# 6               inuvik  68.3499 -133.7218    239.63        68          75
# 7        leningradskiy  69.3833  178.4167    238.82        99          99
#
#          Wind Speed Country        Date
# City_ID
# 1              1.79      US  1675707513
# 2              9.77      US  1675707344
# 5              3.43      GL  1675707636
# 6              2.06      CA  1675707636
# 7              3.47      RU  1675707312

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        beitbridge -22.2167   30.0000    303.07        39          34
# 3           rikitea -23.1203 -134.9692    298.84        74          16
# 4         cape town -33.9258   18.4232    297.23        78          20
# 13          ushuaia -54.8000  -68.3000    286.96        67          75
# 16            ancud -41.8697  -73.8203    289.97        64           4
#
#          Wind Speed Country        Date
# City_ID
# 0              1.86      ZW  1675707635
# 3              2.55      PF  1675707249
# 4              6.17      ZA  1675707083
# 13            10.29      AR  1675707234
# 16             4.10      CL  1675707431

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.text(50,300,line_eq)
plt.show()

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.text(-18,310,line_eq)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** These graphs show that the temperatures of cities generally increase the closer they are to the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.text(50,20,line_eq)
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.text(-15,15,line_eq)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** Humidity seems to increase for cities further away from the equator in the Northern Hemisphere. The opposite appears true in the Southern Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.text(55,50,line_eq)
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.text(-55,66,line_eq)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** There is no real correlation between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.text(5,17,line_eq)
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.text(-55,12,line_eq)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** There doesn't appear to be a strong correlation between latitude and wind speed either.
